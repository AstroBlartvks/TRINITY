# %%
import IMOEX_parser

imoexParser = IMOEX_parser.IMOEXParser()

# %%
imoexParser.start_parse_data("2010-01-01", "2026-09-18")
# Out:
# Парсинг IMOEX:   0%|          | 0/6104 [00:00<?, ?дн/s]
# Expecting value: line 1 column 1 (char 0) | 2010-10-21 -> 2026-09-18
# Expecting value: line 1 column 1 (char 0) | 2012-10-09 -> 2026-09-18
# ('Connection aborted.', ConnectionAbortedError(10053, 'Программа на вашем хост-компьютере разорвала установленное подключение', None, 10053, None)) | 2021-06-10 -> 2026-09-18

# %%
imoexParser.save_data_to_json()
