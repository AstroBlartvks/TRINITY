# %%
import pandas as pd

from RIA_parser import RiaParser

# %%
riaParser = RiaParser()

# %%
all_cal_dates = pd.date_range(
    '2010-01-01', '2026-09-18', freq='B'
).strftime('%Y-%m-%d').tolist()

# %%
news_cache = riaParser.parse_ria_range(all_cal_dates, delay=0.05)
# Out:
#   Кэш загружен: 4361 дней уже есть
#   Нужно спарсить: 0 дней
# Парсинг РИА: 0it [00:00, ?it/s]
#   Итого: 4361 дней, с новостями: 4359
